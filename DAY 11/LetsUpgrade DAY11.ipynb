# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
dataset1=pd.read_csv("general_data.csv")

# %%
dataset1.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 1          1  Life Sciences              1           2  Female  ...
# 2          4          Other              1           3    Male  ...
# 3          5  Life Sciences              1           4    Male  ...
# 4          1        Medical              1           5    Male  ...
#
#    NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# ...

# %%
dataset1.isnull()
# Out:
#         Age  Attrition  BusinessTravel  Department  DistanceFromHome  \
# 0     False      False           False       False             False
# 1     False      False           False       False             False
# 2     False      False           False       False             False
# 3     False      False           False       False             False
# 4     False      False           False       False             False
# ...     ...        ...             ...         ...               ...
# 4405  False      False           False       False             False
# 4406  False      False           False       False             False
# 4407  False      False           False       False             False
# 4408  False      False           False       False             False
# 4409  False      False           False       False             False
#
#       Education  EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# ...

# %%
dataset1.dropna
# Out:
# <bound method DataFrame.dropna of       Age Attrition     BusinessTravel              Department  \
# 0      51        No      Travel_Rarely                   Sales
# 1      31       Yes  Travel_Frequently  Research & Development
# 2      32        No  Travel_Frequently  Research & Development
# 3      38        No         Non-Travel  Research & Development
# 4      32        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4405   42        No      Travel_Rarely  Research & Development
# 4406   29        No      Travel_Rarely  Research & Development
# 4407   25        No      Travel_Rarely  Research & Development
# 4408   42        No      Travel_Rarely                   Sales
# 4409   40        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                    6          2  Life Sciences              1           1
# ...

# %%
dataset1.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4405    False
# 4406    False
# 4407    False
# 4408    False
# 4409    False
# Length: 4410, dtype: bool

# %%
dataset1.drop_duplicates
# Out:
# <bound method DataFrame.drop_duplicates of       Age Attrition     BusinessTravel              Department  \
# 0      51        No      Travel_Rarely                   Sales
# 1      31       Yes  Travel_Frequently  Research & Development
# 2      32        No  Travel_Frequently  Research & Development
# 3      38        No         Non-Travel  Research & Development
# 4      32        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4405   42        No      Travel_Rarely  Research & Development
# 4406   29        No      Travel_Rarely  Research & Development
# 4407   25        No      Travel_Rarely  Research & Development
# 4408   42        No      Travel_Rarely                   Sales
# 4409   40        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                    6          2  Life Sciences              1           1
# ...

# %%
print(dataset1[['Age','DistanceFromHome','Education','MonthlyIncome', 'NumCompaniesWorked', 'PercentSalaryHike','TotalWorkingYears', 'TrainingTimesLastYear', 'YearsAtCompany','YearsSinceLastPromotion', 'YearsWithCurrManager']].describe())
# Out:
#                Age  DistanceFromHome    Education  MonthlyIncome  \
# count  4410.000000       4410.000000  4410.000000    4410.000000
# mean     36.923810          9.192517     2.912925   65029.312925
# std       9.133301          8.105026     1.023933   47068.888559
# min      18.000000          1.000000     1.000000   10090.000000
# 25%      30.000000          2.000000     2.000000   29110.000000
# 50%      36.000000          7.000000     3.000000   49190.000000
# 75%      43.000000         14.000000     4.000000   83800.000000
# max      60.000000         29.000000     5.000000  199990.000000
#
#        NumCompaniesWorked  PercentSalaryHike  TotalWorkingYears  \
# count         4391.000000        4410.000000        4401.000000
# mean             2.694830          15.209524          11.279936
# std              2.498887           3.659108           7.782222
# min              0.000000          11.000000           0.000000
# ...

# %%
from scipy.stats import pearsonr

# %%
lable_mapping = {"Yes":1,"No":0}
df.Attrition = df.Attrition.map(lable_mapping)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-2b8d554c7443> in <module>
#       1 lable_mapping = {"Yes":1,"No":0}
# ----> 2 df.Attrition = df.Attrition.map(lable_mapping)
#
# NameError: name 'df' is not defined

# %%
dataset1['Attrition1'] = dataset1.Attrition.map({"Yes":1,"No":0})

# %%
dataset1
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 0      51        No      Travel_Rarely                   Sales
# 1      31       Yes  Travel_Frequently  Research & Development
# 2      32        No  Travel_Frequently  Research & Development
# 3      38        No         Non-Travel  Research & Development
# 4      32        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4405   42        No      Travel_Rarely  Research & Development
# 4406   29        No      Travel_Rarely  Research & Development
# 4407   25        No      Travel_Rarely  Research & Development
# 4408   42        No      Travel_Rarely                   Sales
# 4409   40        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                    6          2  Life Sciences              1           1
# ...

# %%
stats,p = pearsonr(dataset1.Attrition1,dataset1.Age)

# %% [markdown]
# **NOW WE CAN CHECK THAT THE p VALUE IS LESS THAN 0.05 SO THAT THE NULL HYPOTHESIS IS REJECTED**

# %%
print(stats,p)
# Out:
# -0.15920500686577965 1.996801615886744e-26

# %% [markdown]
# NULL HYPOTHESIS IS REJECTED

# %%
stats,p = pearsonr(dataset1.Attrition1,dataset1.DistanceFromHome)

# %%
print(stats,p)
# Out:
# -0.01812507887701024 0.22881970951795952

# %% [markdown]
# NULL HYPOTHESIS IS NOT REJECTED

# %%
stats,p = pearsonr(dataset1.Attrition1,dataset1.Education)

# %%
print(stats,p)
# Out:
# -0.015111167710968711 0.3157293177118575

# %% [markdown]
# NULL HYPOTHESIS IS NOT REJECTED

# %%
stats,p = pearsonr(dataset1.Attrition1,dataset1.EmployeeID)

# %%
print(stats,p)
# Out:
# -0.004729122995066087 0.7535487401886252

# %% [markdown]
# NULL HYPOTHESIS IS NOT REJECTED

# %%
stats,p = pearsonr(dataset1.Attrition1,dataset1.JobLevel)

# %%
print(stats,p)
# Out:
# -0.010289713287495035 0.49451717271828405

# %% [markdown]
# NULL HYPOTHESIS IS NOT REJECTED

# %%
stats,p = pearsonr(dataset1.Attrition1,dataset1.MonthlyIncome)

# %%
print(stats,p)
# Out:
# -0.031176281698115007 0.03842748490600132

# %% [markdown]
# NULL HYPOTHESIS IS NOT REJECTED

# %%
stats,p = pearsonr(dataset1.Attrition1,dataset1.PercentSalaryHike)

# %%
print(stats,p)
# Out:
# 0.03253259489105351 0.030743386433355353

# %% [markdown]
# NULL HYPOTHESIS IS REJECTED

# %%
stats,p = pearsonr(dataset1.Attrition1,dataset1.StockOptionLevel)

# %%
print(stats,p)
# Out:
# -0.006838852403261521 0.6498072937475723

# %% [markdown]
# NULL HYPOTHESIS IS NOT REJECTED

# %%
stats,p = pearsonr(dataset1.Attrition1,dataset1.TrainingTimesLastYear)

# %%
print(stats,p)
# Out:
# -0.04943057624425501 0.0010247061915362814

# %% [markdown]
# NULL HYPOTHESIS IS REJECTED

# %%
stats,p = pearsonr(dataset1.Attrition1,dataset1.YearsSinceLastPromotion)

# %%
print(stats,p)
# Out:
# -0.03301877514258434 0.028330336189396753

# %% [markdown]
# NULL HYPOTHESIS IS REJECTED

# %%
stats,p = pearsonr(dataset1.Attrition1,dataset1.YearsSinceLastPromotion)

# %%
print(stats,p)
# Out:
# -0.03301877514258434 0.028330336189396753

# %% [markdown]
# NULL HYPOTHESIS IS REJECTED

# %%
stats,p = pearsonr(dataset1.Attrition1,dataset1.YearsWithCurrManager)

# %%
print(stats,p)
# Out:
# -0.15619931590162842 1.7339322652900218e-25

# %% [markdown]
# NULL HYPOTHESIS IS REJECTED

# %%
dataset1['Gender1'] = dataset1.Gender.map({"Female":1,"Male":0})

# %%
dataset1
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 0      51        No      Travel_Rarely                   Sales
# 1      31       Yes  Travel_Frequently  Research & Development
# 2      32        No  Travel_Frequently  Research & Development
# 3      38        No         Non-Travel  Research & Development
# 4      32        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4405   42        No      Travel_Rarely  Research & Development
# 4406   29        No      Travel_Rarely  Research & Development
# 4407   25        No      Travel_Rarely  Research & Development
# 4408   42        No      Travel_Rarely                   Sales
# 4409   40        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                    6          2  Life Sciences              1           1
# ...

# %%
stats,p = pearsonr(dataset1.Attrition1,dataset1.Gender1)

# %%
print(stats,p)
# Out:
# -0.01812507887701024 0.22881970951795952

# %% [markdown]
# NULL HYPOTHESIS IS NOT REJECTED
