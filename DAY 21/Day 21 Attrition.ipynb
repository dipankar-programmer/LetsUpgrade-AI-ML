# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import seaborn as sns

# %% [markdown]
# ### **importing the dataset**

# %%
data=pd.read_csv("general_data.csv")

# %%
data.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 1          1  Life Sciences              1           2  Female  ...
# 2          4          Other              1           3    Male  ...
# 3          5  Life Sciences              1           4    Male  ...
# 4          1        Medical              1           5    Male  ...
#
#    NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# ...

# %% [markdown]
# ### **EDA**

# %%
len(data[data.StandardHours>8])
# Out:
# 0

# %%
len(data[data.Over18=="N"])
# Out:
# 0

# %%
len(data[data.EmployeeCount>1])
# Out:
# 0

# %%
data.drop(["EmployeeID","Over18","StandardHours","EmployeeCount","TotalWorkingYears","NumCompaniesWorked"],axis=1,inplace=True)

# %%
data.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  Gender  JobLevel                    JobRole  \
# 0          2  Life Sciences  Female         1  Healthcare Representative
# 1          1  Life Sciences  Female         1         Research Scientist
# 2          4          Other    Male         4            Sales Executive
# 3          5  Life Sciences    Male         3            Human Resources
# 4          1        Medical    Male         1            Sales Executive
#
# ...

# %%
from sklearn import preprocessing

# %%
label_encoder=preprocessing.LabelEncoder()

# %%
attrition=label_encoder.fit_transform(data["Attrition"])

# %%
data["Attrition"]=attrition

# %%
travel=label_encoder.fit_transform(data["BusinessTravel"])

# %%
data["BusinessTravel"]=travel

# %%
department=label_encoder.fit_transform(data["Department"])

# %%
data["Department"]=department

# %%
education_field=label_encoder.fit_transform(data["EducationField"])

# %%
data["EducationField"]=education_field

# %%
gender=label_encoder.fit_transform(data["Gender"])

# %%
data["Gender"]=gender

# %%
jobrole=label_encoder.fit_transform(data["JobRole"])

# %%
data["JobRole"]=jobrole

# %%
maritalstatus=label_encoder.fit_transform(data["MaritalStatus"])

# %%
data["MaritalStatus"]=maritalstatus

# %%
data.corr()
# Out:
#                               Age  Attrition  BusinessTravel  Department  \
# Age                      1.000000  -0.159205        0.024751   -0.010846
# Attrition               -0.159205   1.000000        0.000074   -0.048206
# BusinessTravel           0.024751   0.000074        1.000000   -0.010982
# Department              -0.010846  -0.048206       -0.010982    1.000000
# DistanceFromHome         0.006963  -0.009730        0.024616    0.012134
# Education               -0.035706  -0.015111        0.002755   -0.004597
# EducationField           0.043194  -0.057940       -0.015462    0.013720
# Gender                  -0.039352   0.018125       -0.039243    0.003158
# JobLevel                -0.002884  -0.010290        0.046111    0.002923
# JobRole                  0.011422   0.025809       -0.027194   -0.025466
# MaritalStatus           -0.095029   0.162070        0.024001   -0.044619
# MonthlyIncome           -0.044314  -0.031176       -0.037597   -0.032237
# ...

# %%
data.isnull().sum()
# Out:
# Age                        0
# Attrition                  0
# BusinessTravel             0
# Department                 0
# DistanceFromHome           0
# Education                  0
# EducationField             0
# Gender                     0
# JobLevel                   0
# JobRole                    0
# MaritalStatus              0
# MonthlyIncome              0
# PercentSalaryHike          0
# StockOptionLevel           0
# TrainingTimesLastYear      0
# YearsAtCompany             0
# YearsSinceLastPromotion    0
# YearsWithCurrManager       0
# dtype: int64

# %% [markdown]
# ### **Splitting the dataset**

# %%
y=data.Attrition

# %%
y
# Out:
# 0       0
# 1       1
# 2       0
# 3       0
# 4       0
#        ..
# 4405    0
# 4406    0
# 4407    0
# 4408    0
# 4409    0
# Name: Attrition, Length: 4410, dtype: int32

# %%
X=data.drop("Attrition",axis=1)

# %%
X
# Out:
#       Age  BusinessTravel  Department  DistanceFromHome  Education  \
# 0      51               2           2                 6          2
# 1      31               1           1                10          1
# 2      32               1           1                17          4
# 3      38               0           1                 2          5
# 4      32               2           1                10          1
# ...   ...             ...         ...               ...        ...
# 4405   42               2           1                 5          4
# 4406   29               2           1                 2          4
# 4407   25               2           1                25          2
# 4408   42               2           2                18          2
# 4409   40               2           1                28          3
#
#       EducationField  Gender  JobLevel  JobRole  MaritalStatus  MonthlyIncome  \
# 0                  1       0         1        0              1         131160
# ...

# %%
X1=sm.add_constant(X)

# %%
Logistic=sm.Logit(y,X1)

# %%
result=Logistic.fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.398822
#          Iterations 7

# %%
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:              Attrition   No. Observations:                 4410
# Model:                          Logit   Df Residuals:                     4392
# Method:                           MLE   Df Model:                           17
# Date:                Sun, 09 Aug 2020   Pseudo R-squ.:                 0.09706
# Time:                        18:27:45   Log-Likelihood:                -1758.8
# converged:                       True   LL-Null:                       -1947.9
# Covariance Type:            nonrobust   LLR p-value:                 6.818e-70
# ...
#                               coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                       0.4663      0.402      1.161      0.246      -0.321       1.254
# ...

# %% [markdown]
# #### **the columns which are important are Age,BusinessTravel,DistanceFrmHome,Education,Gender,JobLevel,MaritialStatus,YearsSinceLastPromotion	and YearsWithCurrManager**
